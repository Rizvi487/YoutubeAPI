# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\Rizwan.shaik\AppData\Local\Temp\ipykernel_4120\3336562545.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
api_key = 'AIzaSyAprmiDktwCKmQTaUC8d6O2AT1iPyO3lHM'
# channel_id = 'UCBJycsmduvYEL83R_U4JriQ'
channel_ids = ['UCBJycsmduvYEL83R_U4JriQ',
               'UCLLw7jmFsvfIVaUFsLs8mlQ',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UC7cs8q-gJRlGwj4A8OmCmXg',
               'UC2UXDak6o7rBm23k3Vv5dww']
youtube = build('youtube','v3',developerKey=api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute()
    for i in range(len(response['items'])):
                       data = dict(Channel_name = response['items'][i]['snippet']['title'],
                       Subscriber= response['items'][i]['statistics']['subscriberCount'],
                       Views = response['items'][i]['statistics']['viewCount'],
                       Total_Videos = response['items'][i]['statistics']['videoCount'],
                        playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
                       all_data.append(data)
                
    return all_data

# %%
channel_statistics = get_channel(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#        Channel_name Subscriber       Views Total_Videos  \
# 0        Tina Huang     611000    28367703          189
# 1           Ken Jee     256000     8834406          286
# 2     Luke Barousse     414000    20593092          154
# 3  Alex The Analyst     701000    30067335          284
# 4  Marques Brownlee   18400000  4071818767         1631
#
#                 playlist_id
# 0  UU2UXDak6o7rBm23k3Vv5dww
# 1  UUiT9RITQ9PW6BhXK0y2jaeg
# 2  UULLw7jmFsvfIVaUFsLs8mlQ
# 3  UU7cs8q-gJRlGwj4A8OmCmXg
# 4  UUBJycsmduvYEL83R_U4JriQ

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscriber      object
# Views           object
# Total_Videos    object
# dtype: object

# %%
channel_data['Subscriber']= pd.to_numeric(channel_data['Subscriber'])
channel_data['Views']= pd.to_numeric(channel_data['Views'])
channel_data['Total_Videos']= pd.to_numeric(channel_data['Total_Videos']  )
channel_data.dtypes
# Out:
# Channel_name    object
# Subscriber       int64
# Views            int64
# Total_Videos     int64
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y='Subscriber', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_Videos', data=channel_data)

# %% [markdown]
# ## Function to get video ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Alex The Analyst', 'playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UU7cs8q-gJRlGwj4A8OmCmXg'

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
              part='contentDetails',
              playlistId= playlist_id,
              maxResults=50)
    response = request.execute()

    return response

# %%
get_video_ids(youtube, playlist_id)
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'f6h9F4NbqGZyDPDK9Ty2Fzmw7sc',
#  'nextPageToken': 'EAAaelBUOkNBVWlFREV5UlVaQ00wSXhRelUzUkVVMFJURW9BVWktNTZuazhhbUVBMUFCV2pZaVEyaG9WbFpVWkdwamVtaDRURmRrUzFWdGVFaGtNbTh3VVZSb1VHSlZUblJYUjJOVFEzZHFOelZ5UTNWQ2FFTjNiMDU0V2lJ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'X1tlWL7zQjeOTHhrb1FBAFgxxBA',
#    'id': 'VVU3Y3M4cS1nSlJsR3dqNEE4T21DbVhnLlJZSWlPRzRMc3ZR',
#    'contentDetails': {'videoId': 'RYIiOG4LsvQ',
#     'videoPublishedAt': '2024-02-13T13:00:19Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'inSyL2bWID5PEk2ZADa9Tew1oow',
#    'id': 'VVU3Y3M4cS1nSlJsR3dqNEE4T21DbVhnLjV5N3RMTlBWSlBB',
#    'contentDetails': {'videoId': '5y7tLNPVJPA',
#     'videoPublishedAt': '2024-02-08T13:59:09Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'wYsXJBPcBau26Y5bejtThkPFVMs',
#    'id': 'VVU3Y3M4cS1nSlJsR3dqNEE4T21DbVhnLl9uZjU2YU1QZFpF',
#    'contentDetails': {'videoId': '_nf56aMPdZE',
#     'videoPublishedAt': '2024-02-06T13:00:35Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'QYYEv0pH7pX9MIiDur7OS80o5sQ',
#    'id': 'VVU3Y3M4cS1nSlJsR3dqNEE4T21DbVhnLlhiRFJZellVbU1v',
#    'contentDetails': {'videoId': 'XbDRYzYUmMo',
#     'videoPublishedAt': '2024-01-30T17:30:05Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'j_nA7mGdxoo5x_Pp3EJ_r-5GGv0',
#    'id': 'VVU3Y3M4cS1nSlJsR3dqNEE4T21DbVhnLktSWFNKYjlxbDFZ',
#    'contentDetails': {'videoId': 'KRXSJb9ql1Y',
#     'videoPublishedAt': '2024-01-30T13:00:17Z'}}],
#  'pageInfo': {'totalResults': 284, 'resultsPerPage': 5}}
